# %% [markdown]
# Use the given dataset of LoanPrediction to predicts if a loan will get approved or not.
#
# Dataset- The data has 615 rows and 13 columns.
#
# Dataset Description- Loan_ID - Unique Loan ID,Gender - Male/ Female,Married- Applicant married (Y/N),Dependents - Number of dependents,Education - Applicant Education (Graduate/ Under Graduate)
#
# 		     Self_Employed - Self employed (Y/N),ApplicantIncome - Applicant income,CoapplicantIncome - Coapplicant income,LoanAmount - Loan amount in thousands
#
# 		     Loan_Amount_Term - Term of loan in months,Credit_History - credit history meets guidelines,Property_Area - Urban/ Semi Urban/ Rural
#
# 		     Loan_Status - Loan approved (Y/N)

# %%
import pandas as pd

# %%
Traindata = pd.read_csv("train.csv")
Traindata.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
Testdata = pd.read_csv("test.csv")
Testdata.sample(5)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 96   LP001500   Male     Yes          1      Graduate            No
# 28   LP001174   Male     Yes          0      Graduate            No
# 22   LP001128    NaN      No          0      Graduate            No
# 20   LP001121   Male     Yes          1  Not Graduate            No
# 352  LP002907   Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 96              3333               4200       256.0             360.0
# 28              3772                833        57.0             360.0
# 22              3909                  0       101.0             360.0
# 20              1888               1620        48.0             360.0
# 352             5817                910       109.0             360.0
#
#      Credit_History Property_Area
# 96              1.0         Urban
# 28              NaN     Semiurban
# 22              1.0         Urban
# 20              1.0         Urban
# 352             1.0         Urban

# %% [markdown]
# ### 1.Find the count of missing values in train dataset(train.csv)?

# %%
Traindata.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ### 2.Combine both the test and train datasets.

# %%
Traindata.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
Testdata.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
print(Testdata.shape)
print(Traindata.shape)
# Out:
# (367, 12)
# (614, 13)

# %%
Data = Traindata.append(Testdata)
Data
# Out:
# D:\anaconda\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#      ApplicantIncome  CoapplicantIncome  Credit_History Dependents  \
# 0               5849                0.0             1.0          0
# 1               4583             1508.0             1.0          1
# 2               3000                0.0             1.0          0
# 3               2583             2358.0             1.0          0
# 4               6000                0.0             1.0          0
# 5               5417             4196.0             1.0          2
# 6               2333             1516.0             1.0          0
# 7               3036             2504.0             0.0         3+
# 8               4006             1526.0             1.0          2
# 9              12841            10968.0             1.0          1
# 10              3200              700.0             1.0          2
# 11              2500             1840.0             1.0          2
# 12              3073             8106.0             1.0          2
# 13              1853             2840.0             1.0          0
# 14              1299             1086.0             1.0          2
# 15              4950                0.0             1.0          0
# 16              3596                0.0             NaN          1
# 17              3510                0.0             0.0          0
# 18              4887                0.0             1.0          0
# 19              2600             3500.0             1.0          0
# 20              7660                0.0             0.0          0
# 21              5955             5625.0             1.0          1
# 22              2600             1911.0             0.0          0
# 23              3365             1917.0             0.0          2
# 24              3717             2925.0             NaN          1
# 25              9560                0.0             1.0          0
# 26              2799             2253.0             1.0          0
# 27              4226             1040.0             1.0          2
# 28              1442                0.0             1.0          0
# 29              3750             2083.0             1.0          2
# ..               ...                ...             ...        ...
# 337             2292             1558.0             1.0          0
# 338             2360             3355.0             1.0          1
# 339             4333             2333.0             0.0          0
# 340             2623             4831.0             1.0          0
# 341             3972             4275.0             1.0          0
# 342             3522                0.0             1.0         3+
# 343             4700                0.0             1.0          1
# 344             6858                0.0             1.0          0
# 345             8334                0.0             1.0         3+
# 346             3391             1966.0             0.0          0
# 347             2868                0.0             1.0          0
# 348             3418             1380.0             1.0          2
# 349             2500              296.0             1.0          0
# 350             8667                0.0             1.0          2
# 351             2283            15000.0             NaN          0
# 352             5817              910.0             1.0          0
# 353             5119             3769.0             1.0          0
# 354             5316              187.0             0.0         3+
# 355             7603             1213.0             1.0         3+
# 356             3791             1936.0             1.0          1
# 357             2500                0.0             1.0          0
# 358             3132                0.0             NaN          2
# 359             4000             2667.0             1.0          0
# 360             8550             4255.0             NaN          0
# 361             2269             2167.0             1.0          1
# 362             4009             1777.0             1.0         3+
# 363             4158              709.0             1.0          0
# 364             3250             1993.0             NaN          0
# 365             5000             2393.0             1.0          0
# 366             9200                0.0             1.0          0
#
#         Education  Gender  LoanAmount  Loan_Amount_Term   Loan_ID Loan_Status  \
# 0        Graduate    Male         NaN             360.0  LP001002           Y
# 1        Graduate    Male       128.0             360.0  LP001003           N
# 2        Graduate    Male        66.0             360.0  LP001005           Y
# 3    Not Graduate    Male       120.0             360.0  LP001006           Y
# 4        Graduate    Male       141.0             360.0  LP001008           Y
# 5        Graduate    Male       267.0             360.0  LP001011           Y
# 6    Not Graduate    Male        95.0             360.0  LP001013           Y
# 7        Graduate    Male       158.0             360.0  LP001014           N
# 8        Graduate    Male       168.0             360.0  LP001018           Y
# 9        Graduate    Male       349.0             360.0  LP001020           N
# 10       Graduate    Male        70.0             360.0  LP001024           Y
# 11       Graduate    Male       109.0             360.0  LP001027           Y
# 12       Graduate    Male       200.0             360.0  LP001028           Y
# 13       Graduate    Male       114.0             360.0  LP001029           N
# 14       Graduate    Male        17.0             120.0  LP001030           Y
# 15       Graduate    Male       125.0             360.0  LP001032           Y
# 16   Not Graduate    Male       100.0             240.0  LP001034           Y
# 17       Graduate  Female        76.0             360.0  LP001036           N
# 18   Not Graduate    Male       133.0             360.0  LP001038           N
# 19       Graduate    Male       115.0               NaN  LP001041           Y
# 20   Not Graduate    Male       104.0             360.0  LP001043           N
# 21       Graduate    Male       315.0             360.0  LP001046           Y
# 22   Not Graduate    Male       116.0             360.0  LP001047           N
# 23   Not Graduate     NaN       112.0             360.0  LP001050           N
# 24       Graduate    Male       151.0             360.0  LP001052           N
# 25       Graduate    Male       191.0             360.0  LP001066           Y
# 26       Graduate    Male       122.0             360.0  LP001068           Y
# 27   Not Graduate    Male       110.0             360.0  LP001073           Y
# 28   Not Graduate    Male        35.0             360.0  LP001086           N
# 29       Graduate  Female       120.0             360.0  LP001087           Y
# ..            ...     ...         ...               ...       ...         ...
# 337      Graduate    Male       119.0             360.0  LP002856         NaN
# 338      Graduate    Male        87.0             240.0  LP002857         NaN
# 339      Graduate  Female       162.0             360.0  LP002858         NaN
# 340      Graduate    Male       122.0             180.0  LP002860         NaN
# 341      Graduate    Male       187.0             360.0  LP002867         NaN
# 342  Not Graduate    Male        81.0             180.0  LP002869         NaN
# 343      Graduate    Male        80.0             360.0  LP002870         NaN
# 344      Graduate    Male       176.0             360.0  LP002876         NaN
# 345      Graduate    Male       260.0             360.0  LP002878         NaN
# 346      Graduate    Male       133.0             360.0  LP002879         NaN
# 347  Not Graduate    Male        70.0             360.0  LP002885         NaN
# 348  Not Graduate    Male       135.0             360.0  LP002890         NaN
# 349      Graduate    Male       137.0             300.0  LP002891         NaN
# 350      Graduate    Male       254.0             360.0  LP002899         NaN
# 351      Graduate    Male       106.0             360.0  LP002901         NaN
# 352      Graduate    Male       109.0             360.0  LP002907         NaN
# 353      Graduate    Male       120.0             360.0  LP002920         NaN
# 354  Not Graduate    Male       158.0             180.0  LP002921         NaN
# 355      Graduate    Male       197.0             360.0  LP002932         NaN
# 356      Graduate    Male        85.0             360.0  LP002935         NaN
# 357      Graduate    Male        60.0             360.0  LP002952         NaN
# 358  Not Graduate    Male        76.0             360.0  LP002954         NaN
# 359      Graduate    Male       152.0             360.0  LP002962         NaN
# 360      Graduate  Female        96.0             360.0  LP002965         NaN
# 361      Graduate    Male        99.0             360.0  LP002969         NaN
# 362  Not Graduate    Male       113.0             360.0  LP002971         NaN
# 363      Graduate    Male       115.0             360.0  LP002975         NaN
# 364      Graduate    Male       126.0             360.0  LP002980         NaN
# 365      Graduate    Male       158.0             360.0  LP002986         NaN
# 366      Graduate    Male        98.0             180.0  LP002989         NaN
#
#     Married Property_Area Self_Employed
# 0        No         Urban            No
# 1       Yes         Rural            No
# 2       Yes         Urban           Yes
# 3       Yes         Urban            No
# 4        No         Urban            No
# 5       Yes         Urban           Yes
# 6       Yes         Urban            No
# 7       Yes     Semiurban            No
# 8       Yes         Urban            No
# 9       Yes     Semiurban            No
# 10      Yes         Urban            No
# 11      Yes         Urban           NaN
# 12      Yes         Urban            No
# 13       No         Rural            No
# 14      Yes         Urban            No
# 15       No         Urban            No
# 16       No         Urban            No
# 17       No         Urban            No
# 18      Yes         Rural            No
# 19      Yes         Urban           NaN
# 20      Yes         Urban            No
# 21      Yes         Urban            No
# 22      Yes     Semiurban            No
# 23      Yes         Rural            No
# 24      Yes     Semiurban           NaN
# 25      Yes     Semiurban           Yes
# 26      Yes     Semiurban            No
# 27      Yes         Urban            No
# 28       No         Urban            No
# 29       No     Semiurban           NaN
# ..      ...           ...           ...
# 337     Yes         Urban            No
# 338     Yes         Rural           Yes
# 339      No         Rural            No
# 340     Yes     Semiurban           Yes
# 341      No         Rural           Yes
# 342     Yes         Rural            No
# 343     Yes         Urban            No
# 344      No         Rural            No
# 345     Yes         Urban            No
# 346     Yes         Rural            No
# 347      No         Urban            No
# 348     Yes         Urban            No
# 349     Yes         Rural           Yes
# 350     Yes         Rural            No
# 351      No         Rural            No
# 352     Yes         Urban            No
# 353     Yes         Rural            No
# 354     Yes     Semiurban            No
# 355     Yes         Urban            No
# 356     Yes         Urban            No
# 357      No         Urban            No
# 358     Yes         Rural            No
# 359      No     Semiurban            No
# 360     Yes         Urban            No
# 361     Yes     Semiurban            No
# 362     Yes         Urban           Yes
# 363     Yes         Urban            No
# 364      No     Semiurban            No
# 365     Yes         Rural            No
# 366      No         Rural           Yes
#
# [981 rows x 13 columns]

# %%
Data.shape
# Out:
# (981, 13)

# %% [markdown]
# ### 3.Convert Gender,Married,Dependents,Education,Self_Employed,Property_Area into numeric form depending on column?

# %%
Data['Gender']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
# 5        Male
# 6        Male
# 7        Male
# 8        Male
# 9        Male
# 10       Male
# 11       Male
# 12       Male
# 13       Male
# 14       Male
# 15       Male
# 16       Male
# 17     Female
# 18       Male
# 19       Male
# 20       Male
# 21       Male
# 22       Male
# 23        NaN
# 24       Male
# 25       Male
# 26       Male
# 27       Male
# 28       Male
# 29     Female
#         ...
# 337      Male
# 338      Male
# 339    Female
# 340      Male
# 341      Male
# 342      Male
# 343      Male
# 344      Male
# 345      Male
# 346      Male
# 347      Male
# 348      Male
# 349      Male
# 350      Male
# 351      Male
# 352      Male
# 353      Male
# 354      Male
# 355      Male
# 356      Male
# 357      Male
# 358      Male
# 359      Male
# 360    Female
# 361      Male
# 362      Male
# 363      Male
# 364      Male
# 365      Male
# 366      Male
# Name: Gender, Length: 981, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
lab_end =  LabelEncoder()
features = ['Gender','Married','Dependents','Education','Self_Employed','Property_Area']
#Data['Gender'] = lab_end.fit_transform(Data['Gender'].astype('str'))

for feature in features:
    Data[feature] = lab_end.fit_transform(Data[feature].astype('str'))
Data
# Out:
#      ApplicantIncome  CoapplicantIncome  Credit_History  Dependents  \
# 0               5849                0.0             1.0           0
# 1               4583             1508.0             1.0           1
# 2               3000                0.0             1.0           0
# 3               2583             2358.0             1.0           0
# 4               6000                0.0             1.0           0
# 5               5417             4196.0             1.0           2
# 6               2333             1516.0             1.0           0
# 7               3036             2504.0             0.0           3
# 8               4006             1526.0             1.0           2
# 9              12841            10968.0             1.0           1
# 10              3200              700.0             1.0           2
# 11              2500             1840.0             1.0           2
# 12              3073             8106.0             1.0           2
# 13              1853             2840.0             1.0           0
# 14              1299             1086.0             1.0           2
# 15              4950                0.0             1.0           0
# 16              3596                0.0             NaN           1
# 17              3510                0.0             0.0           0
# 18              4887                0.0             1.0           0
# 19              2600             3500.0             1.0           0
# 20              7660                0.0             0.0           0
# 21              5955             5625.0             1.0           1
# 22              2600             1911.0             0.0           0
# 23              3365             1917.0             0.0           2
# 24              3717             2925.0             NaN           1
# 25              9560                0.0             1.0           0
# 26              2799             2253.0             1.0           0
# 27              4226             1040.0             1.0           2
# 28              1442                0.0             1.0           0
# 29              3750             2083.0             1.0           2
# ..               ...                ...             ...         ...
# 337             2292             1558.0             1.0           0
# 338             2360             3355.0             1.0           1
# 339             4333             2333.0             0.0           0
# 340             2623             4831.0             1.0           0
# 341             3972             4275.0             1.0           0
# 342             3522                0.0             1.0           3
# 343             4700                0.0             1.0           1
# 344             6858                0.0             1.0           0
# 345             8334                0.0             1.0           3
# 346             3391             1966.0             0.0           0
# 347             2868                0.0             1.0           0
# 348             3418             1380.0             1.0           2
# 349             2500              296.0             1.0           0
# 350             8667                0.0             1.0           2
# 351             2283            15000.0             NaN           0
# 352             5817              910.0             1.0           0
# 353             5119             3769.0             1.0           0
# 354             5316              187.0             0.0           3
# 355             7603             1213.0             1.0           3
# 356             3791             1936.0             1.0           1
# 357             2500                0.0             1.0           0
# 358             3132                0.0             NaN           2
# 359             4000             2667.0             1.0           0
# 360             8550             4255.0             NaN           0
# 361             2269             2167.0             1.0           1
# 362             4009             1777.0             1.0           3
# 363             4158              709.0             1.0           0
# 364             3250             1993.0             NaN           0
# 365             5000             2393.0             1.0           0
# 366             9200                0.0             1.0           0
#
#      Education  Gender  LoanAmount  Loan_Amount_Term   Loan_ID Loan_Status  \
# 0            0       1         NaN             360.0  LP001002           Y
# 1            0       1       128.0             360.0  LP001003           N
# 2            0       1        66.0             360.0  LP001005           Y
# 3            1       1       120.0             360.0  LP001006           Y
# 4            0       1       141.0             360.0  LP001008           Y
# 5            0       1       267.0             360.0  LP001011           Y
# 6            1       1        95.0             360.0  LP001013           Y
# 7            0       1       158.0             360.0  LP001014           N
# 8            0       1       168.0             360.0  LP001018           Y
# 9            0       1       349.0             360.0  LP001020           N
# 10           0       1        70.0             360.0  LP001024           Y
# 11           0       1       109.0             360.0  LP001027           Y
# 12           0       1       200.0             360.0  LP001028           Y
# 13           0       1       114.0             360.0  LP001029           N
# 14           0       1        17.0             120.0  LP001030           Y
# 15           0       1       125.0             360.0  LP001032           Y
# 16           1       1       100.0             240.0  LP001034           Y
# 17           0       0        76.0             360.0  LP001036           N
# 18           1       1       133.0             360.0  LP001038           N
# 19           0       1       115.0               NaN  LP001041           Y
# 20           1       1       104.0             360.0  LP001043           N
# 21           0       1       315.0             360.0  LP001046           Y
# 22           1       1       116.0             360.0  LP001047           N
# 23           1       2       112.0             360.0  LP001050           N
# 24           0       1       151.0             360.0  LP001052           N
# 25           0       1       191.0             360.0  LP001066           Y
# 26           0       1       122.0             360.0  LP001068           Y
# 27           1       1       110.0             360.0  LP001073           Y
# 28           1       1        35.0             360.0  LP001086           N
# 29           0       0       120.0             360.0  LP001087           Y
# ..         ...     ...         ...               ...       ...         ...
# 337          0       1       119.0             360.0  LP002856         NaN
# 338          0       1        87.0             240.0  LP002857         NaN
# 339          0       0       162.0             360.0  LP002858         NaN
# 340          0       1       122.0             180.0  LP002860         NaN
# 341          0       1       187.0             360.0  LP002867         NaN
# 342          1       1        81.0             180.0  LP002869         NaN
# 343          0       1        80.0             360.0  LP002870         NaN
# 344          0       1       176.0             360.0  LP002876         NaN
# 345          0       1       260.0             360.0  LP002878         NaN
# 346          0       1       133.0             360.0  LP002879         NaN
# 347          1       1        70.0             360.0  LP002885         NaN
# 348          1       1       135.0             360.0  LP002890         NaN
# 349          0       1       137.0             300.0  LP002891         NaN
# 350          0       1       254.0             360.0  LP002899         NaN
# 351          0       1       106.0             360.0  LP002901         NaN
# 352          0       1       109.0             360.0  LP002907         NaN
# 353          0       1       120.0             360.0  LP002920         NaN
# 354          1       1       158.0             180.0  LP002921         NaN
# 355          0       1       197.0             360.0  LP002932         NaN
# 356          0       1        85.0             360.0  LP002935         NaN
# 357          0       1        60.0             360.0  LP002952         NaN
# 358          1       1        76.0             360.0  LP002954         NaN
# 359          0       1       152.0             360.0  LP002962         NaN
# 360          0       0        96.0             360.0  LP002965         NaN
# 361          0       1        99.0             360.0  LP002969         NaN
# 362          1       1       113.0             360.0  LP002971         NaN
# 363          0       1       115.0             360.0  LP002975         NaN
# 364          0       1       126.0             360.0  LP002980         NaN
# 365          0       1       158.0             360.0  LP002986         NaN
# 366          0       1        98.0             180.0  LP002989         NaN
#
#      Married  Property_Area  Self_Employed
# 0          0              2              0
# 1          1              0              0
# 2          1              2              1
# 3          1              2              0
# 4          0              2              0
# 5          1              2              1
# 6          1              2              0
# 7          1              1              0
# 8          1              2              0
# 9          1              1              0
# 10         1              2              0
# 11         1              2              2
# 12         1              2              0
# 13         0              0              0
# 14         1              2              0
# 15         0              2              0
# 16         0              2              0
# 17         0              2              0
# 18         1              0              0
# 19         1              2              2
# 20         1              2              0
# 21         1              2              0
# 22         1              1              0
# 23         1              0              0
# 24         1              1              2
# 25         1              1              1
# 26         1              1              0
# 27         1              2              0
# 28         0              2              0
# 29         0              1              2
# ..       ...            ...            ...
# 337        1              2              0
# 338        1              0              1
# 339        0              0              0
# 340        1              1              1
# 341        0              0              1
# 342        1              0              0
# 343        1              2              0
# 344        0              0              0
# 345        1              2              0
# 346        1              0              0
# 347        0              2              0
# 348        1              2              0
# 349        1              0              1
# 350        1              0              0
# 351        0              0              0
# 352        1              2              0
# 353        1              0              0
# 354        1              1              0
# 355        1              2              0
# 356        1              2              0
# 357        0              2              0
# 358        1              0              0
# 359        0              1              0
# 360        1              2              0
# 361        1              1              0
# 362        1              2              1
# 363        1              2              0
# 364        0              1              0
# 365        1              0              0
# 366        0              0              1
#
# [981 rows x 13 columns]

# %% [markdown]
# ### 4.Also show the count for each column mentioned above after converting into numeric form?

# %%
Data['Gender'].value_counts()
# Out:
# 1    775
# 0    182
# 2     24
# Name: Gender, dtype: int64

# %%
for column in Data.columns:
    print(Data[column].value_counts())
# Out:
# 2500     13
# 5000     11
# 3333     10
# 3500      9
# 2600      8
# 4583      7
# 4333      7
# 10000     6
# 2400      6
# 6000      6
# 4000      6
# 4166      6
# 3750      5
# 6250      5
# 8333      5
# 2333      4
# 6500      4
# 3166      4
# 2583      4
# 3417      4
# 7500      4
# 3400      4
# 4283      3
# 5333      3
# 5417      3
# 3000      3
# 3510      3
# 3859      3
# 4750      3
# 3083      3
#          ..
# 6782      1
# 3707      1
# 3704      1
# 2679      1
# 6700      1
# 12876     1
# 4723      1
# 4452      1
# 2699      1
# 12941     1
# 3727      1
# 13083     1
# 5800      1
# 5829      1
# 5124      1
# 3748      1
# 4521      1
# 674       1
# 2720      1
# 3854      1
# 2718      1
# 2717      1
# 1141      1
# 3508      1
# 15000     1
# 14999     1
# 4758      1
# 4755      1
# 4364      1
# 3691      1
# Name: ApplicantIncome, Length: 752, dtype: int64
# 0.0       429
# 2500.0      6
# 2083.0      5
# 2000.0      5
# 2333.0      5
# 1666.0      5
# 700.0       4
# 1800.0      4
# 1250.0      4
# 1750.0      3
# 2250.0      3
# 5625.0      3
# 3167.0      3
# 2925.0      3
# 2900.0      3
# 3750.0      3
# 1300.0      3
# 1625.0      3
# 2166.0      3
# 1917.0      3
# 1500.0      3
# 1560.0      3
# 1083.0      3
# 1459.0      3
# 3583.0      3
# 2400.0      3
# 2167.0      3
# 833.0       2
# 5000.0      2
# 1600.0      2
#          ...
# 7916.0      1
# 2988.0      1
# 2108.0      1
# 5105.0      1
# 7250.0      1
# 4614.0      1
# 2079.0      1
# 3369.0      1
# 2138.0      1
# 1380.0      1
# 2773.0      1
# 2367.0      1
# 828.0       1
# 187.0       1
# 2125.0      1
# 6667.0      1
# 1425.0      1
# 3541.0      1
# 7166.0      1
# 3033.0      1
# 1863.0      1
# 1779.0      1
# 3338.0      1
# 5500.0      1
# 7101.0      1
# 1131.0      1
# 4700.0      1
# 2374.0      1
# 5302.0      1
# 3422.0      1
# Name: CoapplicantIncome, Length: 437, dtype: int64
# 1.0    754
# 0.0    148
# Name: Credit_History, dtype: int64
# 0    545
# 2    160
# 1    160
# 3     91
# 4     25
# Name: Dependents, dtype: int64
# 0    763
# 1    218
# Name: Education, dtype: int64
# 1    775
# 0    182
# 2     24
# Name: Gender, dtype: int64
# 120.0    29
# 110.0    27
# 100.0    24
# 187.0    21
# 150.0    19
# 125.0    18
# 130.0    18
# 160.0    17
# 90.0     15
# 128.0    14
# 135.0    14
# 113.0    14
# 108.0    13
# 95.0     12
# 80.0     12
# 70.0     12
# 96.0     12
# 104.0    12
# 185.0    10
# 132.0    10
# 180.0    10
# 116.0    10
# 138.0    10
# 115.0    10
# 200.0    10
# 140.0     9
# 152.0     9
# 112.0     9
# 122.0     9
# 131.0     9
#          ..
# 296.0     1
# 380.0     1
# 236.0     1
# 308.0     1
# 228.0     1
# 376.0     1
# 89.0      1
# 54.0      1
# 436.0     1
# 304.0     1
# 190.0     1
# 86.0      1
# 336.0     1
# 246.0     1
# 79.0      1
# 256.0     1
# 77.0      1
# 232.0     1
# 57.0      1
# 496.0     1
# 292.0     1
# 36.0      1
# 9.0       1
# 26.0      1
# 324.0     1
# 196.0     1
# 400.0     1
# 250.0     1
# 500.0     1
# 156.0     1
# Name: LoanAmount, Length: 232, dtype: int64
# 360.0    823
# 180.0     66
# 480.0     23
# 300.0     20
# 240.0      8
# 84.0       7
# 120.0      4
# 36.0       3
# 60.0       3
# 12.0       2
# 350.0      1
# 6.0        1
# Name: Loan_Amount_Term, dtype: int64
# LP002816    1
# LP002403    1
# LP002843    1
# LP002786    1
# LP002318    1
# LP001054    1
# LP002168    1
# LP001119    1
# LP001757    1
# LP002385    1
# LP001404    1
# LP002082    1
# LP001347    1
# LP001199    1
# LP002899    1
# LP001273    1
# LP001720    1
# LP001015    1
# LP002231    1
# LP002004    1
# LP002417    1
# LP001430    1
# LP002255    1
# LP001842    1
# LP002502    1
# LP001219    1
# LP001883    1
# LP002223    1
# LP002459    1
# LP001116    1
#            ..
# LP002297    1
# LP002263    1
# LP002116    1
# LP002588    1
# LP002478    1
# LP002183    1
# LP002524    1
# LP002069    1
# LP001728    1
# LP002332    1
# LP002971    1
# LP002390    1
# LP002515    1
# LP001658    1
# LP002619    1
# LP002917    1
# LP002170    1
# LP001475    1
# LP002125    1
# LP002690    1
# LP001914    1
# LP001743    1
# LP002131    1
# LP001151    1
# LP001208    1
# LP001836    1
# LP001238    1
# LP001844    1
# LP002624    1
# LP002699    1
# Name: Loan_ID, Length: 981, dtype: int64
# Y    422
# N    192
# Name: Loan_Status, dtype: int64
# 1    631
# 0    347
# 2      3
# Name: Married, dtype: int64
# 1    349
# 2    342
# 0    290
# Name: Property_Area, dtype: int64
# 0    807
# 1    119
# 2     55
# Name: Self_Employed, dtype: int64

# %% [markdown]
# ### 5.Fill the missing values in Married,Gender,Self_Employed with randint, LoanAmount and Dependents with median,Loan_Amount_Term with mean ?

# %%
columns = ['Married','Gender','Self_Employed']
for column in columns:
    print(Data[[column]].isnull().sum() == 0 )
# Out:
# Married    True
# dtype: bool
# Gender    True
# dtype: bool
# Self_Employed    True
# dtype: bool

# %%
Data[column].mode()
# Out:
# 0    0
# dtype: int32

# %%
Data['Self_Employed'].isnull().sum()
# Out:
# 0

# %%
Data['Self_Employed'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 337    False
# 338    False
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# 344    False
# 345    False
# 346    False
# 347    False
# 348    False
# 349    False
# 350    False
# 351    False
# 352    False
# 353    False
# 354    False
# 355    False
# 356    False
# 357    False
# 358    False
# 359    False
# 360    False
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# 366    False
# Name: Self_Employed, Length: 981, dtype: bool

# %%
import numpy as np
#Data['Self_Employed'] = np.random.randint(0,1)
columns = ['Married','Gender','Self_Employed']
for column in columns:
    if Data[column].isnull() == True:
        Data[column] = np.random.randint(0,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-15614763cee2> in <module>
#       3 columns = ['Married','Gender','Self_Employed']
#       4 for column in columns:
# ----> 5     if Data[column].isnull() == True:
#       6         Data[column] = np.random.randint(0,1)
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
Traindata.Gender = Traindata.Gender.fillna('Male')

# %%
columns = ['Married','Gender','Self_Employed']
for column in columns:
    Data[column].fillna(np.random.randint(0,1),inplace=True)  # randint range don't know

# %%
columns = ['Married','Gender','Self_Employed']
for column in columns:
    Data[column].fillna(Data[column].mode()[0],inplace=True)  # randint range don't know

# %%
columns = ['LoanAmount','Dependents']
for column in columns:
    Data[column].fillna(Data[column].median(),inplace=True)

# %%
columns = ['Loan_Amount_Term']
for column in columns:
    Data[column].fillna(Data[column].mean(),inplace=True)

# %%
Data.isnull().sum()
# Out:
# ApplicantIncome        0
# CoapplicantIncome      0
# Credit_History        79
# Dependents             0
# Education              0
# Gender                 0
# LoanAmount             0
# Loan_Amount_Term       0
# Loan_ID                0
# Loan_Status          367
# Married                0
# Property_Area          0
# Self_Employed          0
# dtype: int64

# %% [markdown]
# ### 6.Finally apply any classification Model and calculate Accuracy ?

# %%
X = Data[['ApplicantIncome']]
X.head()
# Out:
#    ApplicantIncome
# 0             5849
# 1             4583
# 2             3000
# 3             2583
# 4             6000

# %%
y = Data[Data.columns[-1:]]
y.head()
# Out:
#    Self_Employed
# 0              0
# 1              0
# 2              1
# 3              0
# 4              0

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# D:\anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
model.score(X_train,y_train)
# Out:
# 0.8192419825072886

# %%
model.score(X_test,y_test)
# Out:
# 0.8033898305084746

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_test,y_pred)
confusion_matrix(y_test,y_pred)
# Out:
# array([[237,   0,   2],
#        [ 41,   0,   0],
#        [ 15,   0,   0]], dtype=int64)
